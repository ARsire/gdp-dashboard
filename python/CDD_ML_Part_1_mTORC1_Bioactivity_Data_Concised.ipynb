# %% [markdown]
# <a href="https://colab.research.google.com/github/ARsire/gdp-dashboard/blob/main/python/CDD_ML_Part_1_mTORC1_Bioactivity_Data_Concised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
# ---

# %% [markdown]
# ## **ChEMBL Database**

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 789.5 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 4.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Cancer**

# %%
# Target search for cancer
target = new_client.target
target_query = target.search('mTORC1')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references      organism pref_name  \
# 0  [{'xref_id': 'CPX-503', 'xref_name': 'mTORC1 c...  Homo sapiens    mTORC1
# 1                                                 []  Mus musculus    mTORC1
#
#    score  species_group_flag target_chembl_id  \
# 0   20.0               False    CHEMBL4296661
# 1   20.0               False    CHEMBL5465384
#
#                                    target_components      target_type  tax_id
# 0  [{'accession': 'P42345', 'component_descriptio...  PROTEIN COMPLEX    9606
# 1  [{'accession': 'Q9JLN9', 'component_descriptio...  PROTEIN COMPLEX   10090

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human cancer* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL4296661'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 4                                                 None   Not Determined
# ..                                                 ...              ...
# 288  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 289  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 290  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 291  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 292  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('mTORC1_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-10-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 5                                                 None             None
# ..                                                 ...              ...
# 288  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 289  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 290  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 291  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 230

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                            action_type activity_comment  \
# 0                                                 None             None
# 1                                                 None             None
# 2                                                 None             None
# 3                                                 None             None
# 5                                                 None             None
# ..                                                 ...              ...
# 253  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 254  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 255  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 291  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 292  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id activity_properties assay_chembl_id  \
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 230

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL2181527  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# 1        CHEMBL2181526  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# 2        CHEMBL2181525  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# 3        CHEMBL2181524  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# 5        CHEMBL2181522  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# ..                 ...                                                ...
# 253      CHEMBL5422529  CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...
# 254      CHEMBL5399980  CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...
# 255      CHEMBL5441038  CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...
# 291      CHEMBL4475248  CC(F)(F)CN1C(=O)[C@]2(C)COCCN2c2nc(-c3ccc(NC(=...
# 292      CHEMBL5420465  C[C@@]12COCCN1c1nc(-c3cccc4[nH]ccc34)ncc1N([C@...
#
#     standard_value
# 0             62.0
# 1             19.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('mTORC1_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('mTORC1_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL2181527  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# 1        CHEMBL2181526  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# 2        CHEMBL2181525  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# 3        CHEMBL2181524  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# 4        CHEMBL2181522  CCNC(=O)Nc1ccc(-c2nc3c(c(N4CCOC[C@@H]4C)n2)CCN...
# ..                 ...                                                ...
# 225      CHEMBL5422529  CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...
# 226      CHEMBL5399980  CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...
# 227      CHEMBL5441038  CO[C@H]1C[C@@H]2CC[C@@H](C)[C@@](O)(O2)C(=O)C(...
# 228      CHEMBL4475248  CC(F)(F)CN1C(=O)[C@]2(C)COCCN2c2nc(-c3ccc(NC(=...
# 229      CHEMBL5420465  C[C@@]12COCCN1c1nc(-c3cccc4[nH]ccc34)ncc1N([C@...
#
#      standard_value   class
# 0             62.00  active
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('mTORC1_03_bioactivity_data_curated.csv', index=False)

# %%
! zip mTORC1.zip *.csv
# Out:
#   adding: mTORC1_01_bioactivity_data_raw.csv (deflated 93%)
#   adding: mTORC1_02_bioactivity_data_preprocessed.csv (deflated 85%)
#   adding: mTORC1_03_bioactivity_data_curated.csv (deflated 85%)

# %%
! ls -l
# Out:
# total 312
# -rw-r--r-- 1 root root  25534 Jan 26 08:19 acetylcholinesterase.zip
# -rw-r--r-- 1 root root 222121 Jan 26 08:11 mTORC1_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  27254 Jan 26 08:14 mTORC1_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  28924 Jan 26 08:19 mTORC1_03_bioactivity_data_curated.csv
# drwxr-xr-x 1 root root   4096 Jan 23 14:24 sample_data

# %% [markdown]
# ---
